# %%
import numpy as np
import tensorflow as tf
from collections import defaultdict
from skimage import io
from keras import layers
from keras.layers import Dropout, Input, concatenate
from keras import models
from keras.models import Model, load_model
from keras import backend as K
from keras.applications import ResNet50
from keras import models
from keras.models import Model, Sequential
from keras.layers import Dropout
import matplotlib.pyplot as plt
from sklearn.utils.multiclass import unique_labels
from sklearn.manifold import TSNE
from sklearn.model_selection import train_test_split
from keras.applications import ResNet50
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# # Loss function

# %%
def triplet_loss(y_true, y_pred):
  del y_true

  total_lenght = y_pred.shape.as_list()[-1]   
   
  anchor = y_pred[:,0:int(total_lenght*1/3)]
  positive = y_pred[:,int(total_lenght*1/3):int(total_lenght*2/3)]
  negative = y_pred[:,int(total_lenght*2/3):int(total_lenght*3/3)]

  dist = "qeuclidean"
  margin = "softplus"

  positive_distance = K.square(anchor - positive)
  negative_distance = K.square(anchor - negative)
  if dist == "sqeuclidean":
    positive_distance = K.mean(positive_distance, axis=-1, keepdims=True)
    negative_distance = K.mean(negative_distance, axis=-1, keepdims=True)
  elif dist == "qeuclidean":
    positive_distance = tf.math.sqrt(K.sum(positive_distance, axis=-1, keepdims=True))
    negative_distance = tf.math.sqrt(K.sum(negative_distance, axis=-1, keepdims=True))
  loss = positive_distance - negative_distance
  if margin == "maxplus":
    loss = K.maximum(0.0, 1+loss)
  elif margin == 'softplus':
    loss = K.log(1 + K.exp(loss))

  return K.mean(loss)

# %% [markdown]
# # Accuracy function

# %%
def accuracy(y_true, y_pred):
  del y_true

  total_lenght = y_pred.shape.as_list()[-1]  

  anchor = y_pred[:,0:int(total_lenght*1/3)]
  positive = y_pred[:,int(total_lenght*1/3):int(total_lenght*2/3)]
  negative = y_pred[:,int(total_lenght*2/3):int(total_lenght*3/3)]
  
  positive_distance = K.square(anchor - positive)
  negative_distance = K.square(anchor - negative)
  positive_distance = tf.math.sqrt(K.sum(positive_distance, axis=-1, keepdims=True))
  negative_distance = tf.math.sqrt(K.sum(negative_distance, axis=-1, keepdims=True))
    
  return K.mean(positive_distance < negative_distance)

# %% [markdown]
# # Embedding model

# %%
def embedding_model_function(input_shape):

  base_input = Input(input_shape)
  x1 = layers.Conv2D(128, (3, 3), activation='relu')(base_input)
  x1 = layers.MaxPooling2D((2, 2))(x1)
  x1 = layers.Conv2D(128, (3, 3), activation='relu')(x1)
  x1 = layers.MaxPooling2D((2, 2))(x1)
  x1 = layers.Conv2D(128, (3, 3), activation='relu')(x1)
  x1 = layers.MaxPooling2D((2, 2))(x1)
  x1 = layers.Conv2D(128, (3, 3), activation='relu')(x1)
  x1 = layers.MaxPooling2D((2, 2))(x1)
  x1 = layers.Dropout(0.25)(x1)
  x1 = layers.Flatten()(x1)
  x1 = layers.Dense(64, activation='linear')(x1)
  embedding_model = Model(base_input, x1, name='embedding')

  return embedding_model

# %%
embedding_model = embedding_model_function((224, 224, 3))
embedding_model.summary()
# Out:
# Model: "embedding"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_16 (InputLayer)        (None, 224, 224, 3)       0
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 222, 222, 128)     3584
# _________________________________________________________________
# max_pooling2d_61 (MaxPooling (None, 111, 111, 128)     0
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 109, 109, 128)     147584
# _________________________________________________________________
# max_pooling2d_62 (MaxPooling (None, 54, 54, 128)       0
# _________________________________________________________________
# conv2d_63 (Conv2D)           (None, 52, 52, 128)       147584
# _________________________________________________________________
# max_pooling2d_63 (MaxPooling (None, 26, 26, 128)       0
# _________________________________________________________________
# conv2d_64 (Conv2D)           (None, 24, 24, 128)       147584
# _________________________________________________________________
# max_pooling2d_64 (MaxPooling (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 12, 12, 128)       0
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 18432)             0
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                1179712
# =================================================================
# Total params: 1,626,048
# Trainable params: 1,626,048
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Triplet model

# %%
def triplet_model_function(embedding_model, input_shape):
  anchor_input = Input(input_shape, name='anchor_input')
  positive_input = Input(input_shape, name='positive_input')
  negative_input = Input(input_shape, name='negative_input')
    
  anchor_embedding = embedding_model(anchor_input)
  positive_embedding = embedding_model(positive_input)
  negative_embedding = embedding_model(negative_input)

  inputs = [anchor_input, positive_input, negative_input]
  merged_vector = concatenate([anchor_embedding, positive_embedding, negative_embedding], axis=-1, name='merged_layer')

  triplet_model = Model(inputs=inputs, outputs=merged_vector)

  return triplet_model

# %% [markdown]
# # Functions for triplets generation (faseScrub)

# %%
def get_triples_indices(grouped, n):
    num_classes = len(grouped)
    list_labels = list(grouped.keys())
    list_labels_copy = list_labels.copy()
    for label in list_labels_copy:
      if len(grouped[label]) < 2:
        list_labels.remove(label)
    pairs = []
    for i in range(0,n,1):
        pairs.append(np.random.choice(list_labels, size=2, replace = False))
    pairs = np.array(pairs)
    positive_labels = pairs[:,0]
    negative_labels = pairs[:,1]
    triples_indices = []
    for positive_label, negative_label in zip(positive_labels, negative_labels):
        negative = np.random.choice(grouped[negative_label])
        positive_group = grouped[positive_label]
        m = len(positive_group)
        anchor_j = np.random.randint(0, m)
        anchor = positive_group[anchor_j]
        positive_j = (np.random.randint(1, m) + anchor_j) % m
        positive = positive_group[positive_j]
        triples_indices.append([anchor, positive, negative])
    return np.asarray(triples_indices)

def get_triples_data(x, grouped, n, image_path):
    indices = get_triples_indices(grouped, n)
    x1,x2,x3 = [],[],[]
    for i in indices[:,0]:
      x1.append(io.imread(image_path + "/" + str(x[i]) + ".jpg"))
    for i in indices[:,1]:
      x2.append(io.imread(image_path + "/" + str(x[i]) + ".jpg"))
    for i in indices[:,2]:
      x3.append(io.imread(image_path + "/" + str(x[i]) + ".jpg"))
    x1 = np.array(x1)
    x2 = np.array(x2)
    x3 = np.array(x3)
    return x1/255, x2/255, x3/255
    
def triplet_generator(x, y, batch_size, image_path):
    grouped = defaultdict(list)
    for i, label in enumerate(y):
        grouped[label].append(i)
       
    while True:
        x_anchor, x_positive, x_negative = get_triples_data(x, grouped, batch_size, image_path)
        yield ({'anchor_input': x_anchor,
               'positive_input': x_positive,
               'negative_input': x_negative},
               np.zeros(len(x_anchor)))

# %% [markdown]
# # Reading metadata

# %%
# !cp -a "/content/drive/My Drive/Colab/Roonyx/Face recognition/faceScrub/croped_images_224" "/content/croped_images_224"
# !cp -a "/content/drive/My Drive/Colab/Roonyx/Face recognition/faceScrub/metadata/metadata_small.npz" "/content/metadata_small.npz"

# %%
readed = np.load('/content/metadata_small.npz')
metadata = readed["metadata_small"]
x = metadata[:,0]
x = np.array(x, dtype='int64')
y = metadata[:,1]
y = np.array(y, dtype='int64')
X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=0)

# %% [markdown]
# # Model training

# %%
embedding_model = embedding_model_function(input_shape = (224, 224, 3))
triplet_model = triplet_model_function(embedding_model, input_shape = (224, 224, 3))
triplet_model.compile(loss=triplet_loss, optimizer="adam", metrics = [accuracy])

batch_size = 20
image_path = "/content/croped_images_224"

checkpoint = ModelCheckpoint(filepath = '/content/drive/My Drive/Colab/Roonyx/Face recognition/06.06.2020/BEST_RESULTS',
                             monitor='val_accuracy',
                             verbose=0,
                             save_best_only=True,
                             mode='auto',
                             period=1)

history = triplet_model.fit_generator(triplet_generator(X_train, y_train, batch_size, image_path),
                                      steps_per_epoch=20,
                                      epochs=70,
                                      validation_data=triplet_generator(X_test, y_test, batch_size, image_path),
                                      validation_steps = 20,
                                      verbose=1,
                                      callbacks=[checkpoint])
# Out:
# Epoch 1/70
# 20/20 [==============================] - 11s 526ms/step - loss: 0.6606 - accuracy: 0.5825 - val_loss: 0.4806 - val_accuracy: 0.6250
# Epoch 2/70
# 20/20 [==============================] - 9s 429ms/step - loss: 0.6268 - accuracy: 0.6800 - val_loss: 0.6550 - val_accuracy: 0.6525
# Epoch 3/70
# 20/20 [==============================] - 8s 424ms/step - loss: 0.6015 - accuracy: 0.6600 - val_loss: 0.4726 - val_accuracy: 0.7075
# Epoch 4/70
# 20/20 [==============================] - 8s 421ms/step - loss: 0.5053 - accuracy: 0.7350 - val_loss: 0.4092 - val_accuracy: 0.7200
# Epoch 5/70
# 20/20 [==============================] - 8s 418ms/step - loss: 0.4560 - accuracy: 0.7500 - val_loss: 0.3733 - val_accuracy: 0.7875
# Epoch 6/70
# 20/20 [==============================] - 8s 417ms/step - loss: 0.3827 - accuracy: 0.8000 - val_loss: 0.4005 - val_accuracy: 0.7125
# Epoch 7/70
# 20/20 [==============================] - 8s 414ms/step - loss: 0.3973 - accuracy: 0.8200 - val_loss: 0.6832 - val_accuracy: 0.7975
# Epoch 8/70
# 20/20 [==============================] - 8s 419ms/step - loss: 0.3274 - accuracy: 0.8525 - val_loss: 0.7532 - val_accuracy: 0.7750
# Epoch 9/70
# 20/20 [==============================] - 8s 415ms/step - loss: 0.2987 - accuracy: 0.8725 - val_loss: 0.4984 - val_accuracy: 0.7925
# Epoch 10/70
# 20/20 [==============================] - 8s 416ms/step - loss: 0.3244 - accuracy: 0.8650 - val_loss: 0.7400 - val_accuracy: 0.7825
# Epoch 11/70
# 20/20 [==============================] - 8s 418ms/step - loss: 0.3106 - accuracy: 0.8725 - val_loss: 0.6317 - val_accuracy: 0.7425
# Epoch 12/70
# 20/20 [==============================] - 8s 419ms/step - loss: 0.3382 - accuracy: 0.8300 - val_loss: 0.5616 - val_accuracy: 0.8150
# Epoch 13/70
# 20/20 [==============================] - 8s 418ms/step - loss: 0.2588 - accuracy: 0.9075 - val_loss: 0.4827 - val_accuracy: 0.7850
# Epoch 14/70
# 20/20 [==============================] - 8s 414ms/step - loss: 0.2273 - accuracy: 0.9150 - val_loss: 0.8834 - val_accuracy: 0.8000
# Epoch 15/70
# 20/20 [==============================] - 8s 414ms/step - loss: 0.2062 - accuracy: 0.9275 - val_loss: 0.3391 - val_accuracy: 0.8225
# Epoch 16/70
# 20/20 [==============================] - 8s 416ms/step - loss: 0.2031 - accuracy: 0.9100 - val_loss: 0.2405 - val_accuracy: 0.8025
# Epoch 17/70
# 20/20 [==============================] - 8s 415ms/step - loss: 0.1426 - accuracy: 0.9400 - val_loss: 0.0253 - val_accuracy: 0.8425
# Epoch 18/70
# 20/20 [==============================] - 8s 416ms/step - loss: 0.2307 - accuracy: 0.9075 - val_loss: 0.5653 - val_accuracy: 0.7700
# Epoch 19/70
# 20/20 [==============================] - 8s 416ms/step - loss: 0.1645 - accuracy: 0.9425 - val_loss: 0.2569 - val_accuracy: 0.7900
# Epoch 20/70
# 20/20 [==============================] - 8s 414ms/step - loss: 0.1800 - accuracy: 0.9250 - val_loss: 0.5130 - val_accuracy: 0.7950
# Epoch 21/70
# 20/20 [==============================] - 8s 414ms/step - loss: 0.1636 - accuracy: 0.9275 - val_loss: 0.7819 - val_accuracy: 0.7825
# Epoch 22/70
# 20/20 [==============================] - 8s 415ms/step - loss: 0.1594 - accuracy: 0.9475 - val_loss: 0.2863 - val_accuracy: 0.8150
# Epoch 23/70
# 20/20 [==============================] - 8s 413ms/step - loss: 0.0965 - accuracy: 0.9525 - val_loss: 0.4207 - val_accuracy: 0.8150
# Epoch 24/70
# 20/20 [==============================] - 8s 415ms/step - loss: 0.1451 - accuracy: 0.9525 - val_loss: 0.7733 - val_accuracy: 0.8050
# Epoch 25/70
# 20/20 [==============================] - 8s 414ms/step - loss: 0.1284 - accuracy: 0.9400 - val_loss: 0.3407 - val_accuracy: 0.7850
# Epoch 26/70
# 20/20 [==============================] - 8s 412ms/step - loss: 0.1432 - accuracy: 0.9425 - val_loss: 0.7118 - val_accuracy: 0.7950
# Epoch 27/70
# 20/20 [==============================] - 8s 415ms/step - loss: 0.1299 - accuracy: 0.9500 - val_loss: 0.4087 - val_accuracy: 0.8200
# Epoch 28/70
# 20/20 [==============================] - 8s 413ms/step - loss: 0.1104 - accuracy: 0.9575 - val_loss: 0.2904 - val_accuracy: 0.8325
# Epoch 29/70
# 20/20 [==============================] - 8s 413ms/step - loss: 0.0810 - accuracy: 0.9725 - val_loss: 0.6167 - val_accuracy: 0.8175
# Epoch 30/70
# 20/20 [==============================] - 8s 413ms/step - loss: 0.0882 - accuracy: 0.9625 - val_loss: 0.2216 - val_accuracy: 0.8175
# Epoch 31/70
# 20/20 [==============================] - 8s 415ms/step - loss: 0.1167 - accuracy: 0.9550 - val_loss: 0.6302 - val_accuracy: 0.8325
# Epoch 32/70
# 20/20 [==============================] - 8s 413ms/step - loss: 0.0933 - accuracy: 0.9575 - val_loss: 0.7026 - val_accuracy: 0.8400
# Epoch 33/70
# 20/20 [==============================] - 8s 414ms/step - loss: 0.1074 - accuracy: 0.9550 - val_loss: 0.0637 - val_accuracy: 0.7975
# Epoch 34/70
# 20/20 [==============================] - 8s 415ms/step - loss: 0.1069 - accuracy: 0.9625 - val_loss: 0.4841 - val_accuracy: 0.7725
# Epoch 35/70
# 20/20 [==============================] - 8s 415ms/step - loss: 0.0944 - accuracy: 0.9525 - val_loss: 0.7736 - val_accuracy: 0.8350
# Epoch 36/70
# 20/20 [==============================] - 8s 414ms/step - loss: 0.0985 - accuracy: 0.9525 - val_loss: 0.1456 - val_accuracy: 0.8225
# Epoch 37/70
# 20/20 [==============================] - 8s 414ms/step - loss: 0.1086 - accuracy: 0.9550 - val_loss: 0.2691 - val_accuracy: 0.8500
# Epoch 38/70
# 20/20 [==============================] - 8s 415ms/step - loss: 0.0935 - accuracy: 0.9675 - val_loss: 0.1417 - val_accuracy: 0.8325
# Epoch 39/70
# 20/20 [==============================] - 8s 412ms/step - loss: 0.0761 - accuracy: 0.9650 - val_loss: 0.4638 - val_accuracy: 0.8500
# Epoch 40/70
# 20/20 [==============================] - 8s 417ms/step - loss: 0.0738 - accuracy: 0.9750 - val_loss: 0.0889 - val_accuracy: 0.8375
# Epoch 41/70
# 20/20 [==============================] - 8s 413ms/step - loss: 0.1113 - accuracy: 0.9525 - val_loss: 0.3417 - val_accuracy: 0.8375
# Epoch 42/70
# 20/20 [==============================] - 8s 413ms/step - loss: 0.0608 - accuracy: 0.9775 - val_loss: 0.7723 - val_accuracy: 0.8300
# Epoch 43/70
# 20/20 [==============================] - 8s 416ms/step - loss: 0.1044 - accuracy: 0.9500 - val_loss: 0.3494 - val_accuracy: 0.8200
# Epoch 44/70
# 20/20 [==============================] - 8s 413ms/step - loss: 0.1096 - accuracy: 0.9475 - val_loss: 0.3719 - val_accuracy: 0.8325
# Epoch 45/70
# 20/20 [==============================] - 8s 413ms/step - loss: 0.1309 - accuracy: 0.9450 - val_loss: 0.3302 - val_accuracy: 0.8275
# Epoch 46/70
# 20/20 [==============================] - 8s 413ms/step - loss: 0.0946 - accuracy: 0.9675 - val_loss: 0.1584 - val_accuracy: 0.8775
# Epoch 47/70
# 20/20 [==============================] - 8s 415ms/step - loss: 0.0879 - accuracy: 0.9700 - val_loss: 0.4320 - val_accuracy: 0.8550
# Epoch 48/70
# 20/20 [==============================] - 8s 412ms/step - loss: 0.0819 - accuracy: 0.9700 - val_loss: 0.2504 - val_accuracy: 0.8350
# Epoch 49/70
# 20/20 [==============================] - 8s 413ms/step - loss: 0.0528 - accuracy: 0.9750 - val_loss: 0.6607 - val_accuracy: 0.8325
# Epoch 50/70
# 20/20 [==============================] - 8s 415ms/step - loss: 0.0601 - accuracy: 0.9750 - val_loss: 0.2247 - val_accuracy: 0.8700
# Epoch 51/70
# 20/20 [==============================] - 8s 413ms/step - loss: 0.0515 - accuracy: 0.9800 - val_loss: 0.3598 - val_accuracy: 0.8900
# Epoch 52/70
# 20/20 [==============================] - 8s 415ms/step - loss: 0.0762 - accuracy: 0.9700 - val_loss: 0.3899 - val_accuracy: 0.8475
# Epoch 53/70
# 20/20 [==============================] - 8s 415ms/step - loss: 0.0551 - accuracy: 0.9750 - val_loss: 0.1295 - val_accuracy: 0.8750
# Epoch 54/70
# 20/20 [==============================] - 8s 415ms/step - loss: 0.0385 - accuracy: 0.9850 - val_loss: 0.4059 - val_accuracy: 0.8625
# Epoch 55/70
# 20/20 [==============================] - 8s 414ms/step - loss: 0.0731 - accuracy: 0.9675 - val_loss: 0.3306 - val_accuracy: 0.8375
# Epoch 56/70
# 20/20 [==============================] - 8s 416ms/step - loss: 0.0502 - accuracy: 0.9825 - val_loss: 0.3630 - val_accuracy: 0.8750
# Epoch 57/70
# 20/20 [==============================] - 8s 414ms/step - loss: 0.0602 - accuracy: 0.9825 - val_loss: 0.3256 - val_accuracy: 0.8400
# Epoch 58/70
# 20/20 [==============================] - 8s 418ms/step - loss: 0.0787 - accuracy: 0.9675 - val_loss: 0.5854 - val_accuracy: 0.8350
# Epoch 59/70
# 20/20 [==============================] - 8s 414ms/step - loss: 0.0329 - accuracy: 0.9850 - val_loss: 0.1653 - val_accuracy: 0.8475
# Epoch 60/70
# 20/20 [==============================] - 8s 415ms/step - loss: 0.0280 - accuracy: 0.9900 - val_loss: 0.4737 - val_accuracy: 0.8500
# Epoch 61/70
# 20/20 [==============================] - 8s 416ms/step - loss: 0.0520 - accuracy: 0.9825 - val_loss: 0.5460 - val_accuracy: 0.8150
# Epoch 62/70
# 20/20 [==============================] - 8s 414ms/step - loss: 0.0668 - accuracy: 0.9700 - val_loss: 0.6311 - val_accuracy: 0.8325
# Epoch 63/70
# 20/20 [==============================] - 8s 412ms/step - loss: 0.0546 - accuracy: 0.9800 - val_loss: 0.5268 - val_accuracy: 0.8425
# Epoch 64/70
# 20/20 [==============================] - 8s 414ms/step - loss: 0.0452 - accuracy: 0.9875 - val_loss: 0.6353 - val_accuracy: 0.8550
# Epoch 65/70
# 20/20 [==============================] - 8s 414ms/step - loss: 0.0586 - accuracy: 0.9825 - val_loss: 0.5353 - val_accuracy: 0.8700
# Epoch 66/70
# 20/20 [==============================] - 8s 412ms/step - loss: 0.0267 - accuracy: 0.9925 - val_loss: 0.1529 - val_accuracy: 0.8475
# Epoch 67/70
# 20/20 [==============================] - 8s 413ms/step - loss: 0.0487 - accuracy: 0.9750 - val_loss: 1.0090 - val_accuracy: 0.8475
# Epoch 68/70
# 20/20 [==============================] - 8s 413ms/step - loss: 0.0483 - accuracy: 0.9825 - val_loss: 0.5474 - val_accuracy: 0.8800
# Epoch 69/70
# 20/20 [==============================] - 8s 414ms/step - loss: 0.0433 - accuracy: 0.9825 - val_loss: 0.3045 - val_accuracy: 0.8200
# Epoch 70/70
# 20/20 [==============================] - 8s 413ms/step - loss: 0.0454 - accuracy: 0.9800 - val_loss: 0.8534 - val_accuracy: 0.8650

# %% [markdown]
# # Model loss and accuracy

# %%
plt.figure(figsize=(15,6))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# %%
# triplet_model.save("/content/drive/My Drive/Colab/Roonyx/Face recognition/07.06.2020/" + 'MODEL_triplet.h5')
# embedding_model.save("/content/drive/My Drive/Colab/Roonyx/Face recognition/07.06.2020/" + 'MODEL_embedding.h5')

# %% [markdown]
# # Load saved encoder

# %%
embedding_model = load_model('/content/drive/My Drive/Colab/Roonyx/Face recognition/07.06.2020/MODEL_embedding.h5')

# %% [markdown]
# # Example of prediction

# %%
image_path = "/content/croped_images_224"
data = triplet_generator(X_test,y_test,1,image_path)

for item in data:
  triplet = item
  break

anchor = triplet[0]["anchor_input"]
positive = triplet[0]["positive_input"]
negative = triplet[0]["negative_input"]

images = [anchor[0], positive[0], negative[0]]
names = ["anchor", "positive", "negative"]
fix,axes = plt.subplots(1,3, figsize=(10,4), subplot_kw={'xticks':(),'yticks':()})
for name, image, ax in zip(names, images, axes.ravel()):
    ax.imshow(image)
    ax.set_title(name)

# %%
embedding_anchor = embedding_model.predict(anchor)
embedding_positive = embedding_model.predict(positive)
embedding_negative = embedding_model.predict(negative)

positive_distance = np.sum((embedding_anchor[0] - embedding_positive[0])**2)
negative_distance = np.sum((embedding_anchor[0] - embedding_negative[0])**2)

print("Distance anchor-positive: ", positive_distance)
print("Distance anchor-negative: ", negative_distance)
if positive_distance < negative_distance:
  print("True!")
else: print("False")
# Out:
# Distance anchor-positive:  81.82193
# Distance anchor-negative:  407.9256
# True!

# %% [markdown]
# # Test model on 1000 triplets generated with test data

# %%
image_path = "/content/croped_images_224"
data = triplet_generator(X_test,y_test,1,image_path)
triplets = []
num = 0
for item in data:
  triplets.append(item)
  num+=1
  if num==1000:
    break

num_true = 0
num_false = 0

for i in range(0,1000,1):

  anchor = triplets[i][0]["anchor_input"]
  positive = triplets[i][0]["positive_input"]
  negative = triplets[i][0]["negative_input"]

  embedding_anchor = embedding_model.predict(anchor)
  embedding_positive = embedding_model.predict(positive)
  embedding_negative = embedding_model.predict(negative)

  positive_distance = np.sum((embedding_anchor[0] - embedding_positive[0])**2)
  negative_distance = np.sum((embedding_anchor[0] - embedding_negative[0])**2)

  if positive_distance < negative_distance:
    num_true+=1
  else: num_false+=1

print("num true: ", num_true)
print("num false: ", num_false)
print("Accuracy: {:.2f}%".format(num_true/((num_true+num_false)/100)))
# Out:
# num true:  857
# num false:  143
# Accuracy: 85.70%

# %% [markdown]
# # Calculation of model operating time

# %%
# %%time
embedding_anchor = embedding_model.predict(anchor)
# Out:
# CPU times: user 6.01 ms, sys: 0 ns, total: 6.01 ms
# Wall time: 7.73 ms
