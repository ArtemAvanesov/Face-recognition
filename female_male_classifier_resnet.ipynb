# %%
import numpy as np
from keras import models
from keras.models import Model, load_model
from keras import layers
from keras.layers import Dropout, Input
from keras import backend as K
from sklearn.model_selection import train_test_split
import shutil
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %% [markdown]
# # Load encoder model

# %%
embedding_model = load_model('/content/drive/My Drive/Colab/Roonyx/Face recognition/07.06.2020/MODEL_embedding_facenet.h5')
embedding_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 2048)              23587712
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               65664
# =================================================================
# Total params: 26,276,352
# Trainable params: 26,223,232
# Non-trainable params: 53,120
# _________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %% [markdown]
# # Model for female/male classification

# %%
def model_function(input_shape):

  base_input = Input(input_shape) 
  embedding_layers = embedding_model.layers[:-1]
  x1 = embedding_layers[0](base_input)
  for i in range(1,len(embedding_layers),1):
    x1 = embedding_layers[i](x1)

  x1 = layers.Dense(1, activation='sigmoid')(x1)

  model = Model(base_input, x1, name='female_male')

  for i in range(0,6,1):
    model.layers[i].trainable = False

  return model

# %%
model = model_function((224, 224, 3))
model.summary()
# Out:
# Model: "female_male"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# resnet50 (Model)             (None, 2048)              23587712
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 2048)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1024)              2098176
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 26,211,201
# Trainable params: 513
# Non-trainable params: 26,210,688
# _________________________________________________________________

# %% [markdown]
# # Reading metadata

# %%
# !cp -a "/content/drive/My Drive/Colab/Roonyx/Face recognition/faceScrub/croped_images_224" "/content/croped_images_224"
# !cp -a "/content/drive/My Drive/Colab/Roonyx/Face recognition/faceScrub/metadata/metadata_small.npz" "/content/metadata_small.npz"

# %%
readed = np.load('/content/metadata_small.npz')
metadata = readed["metadata_small"]
x = metadata[:,0]
x = np.array(x, dtype='int64')
y = metadata[:,3]
y = np.array(y)
X_train, X_test, y_train, y_test = train_test_split(x, y, random_state=0)

# !mkdir "/content/test"
# !mkdir "/content/test/male"
# !mkdir "/content/test/female"
# !mkdir "/content/train"
# !mkdir "/content/train/male"
# !mkdir "/content/train/female"

for i in range(0,len(X_train),1):
  if(y_train[i]=="female"):
    shutil.copy("/content/croped_images_224/" + str(X_train[i]) + ".jpg", "/content/train/female/" + str(X_train[i]) + ".jpg")
  else: shutil.copy("/content/croped_images_224/" + str(X_train[i]) + ".jpg", "/content/train/male/" + str(X_train[i]) + ".jpg")
  
for i in range(0,len(X_test),1):
  if(y_test[i]=="female"):
    shutil.copy("/content/croped_images_224/" + str(X_test[i]) + ".jpg", "/content/test/female/" + str(X_test[i]) + ".jpg")
  else: shutil.copy("/content/croped_images_224/" + str(X_test[i]) + ".jpg", "/content/test/male/" + str(X_test[i]) + ".jpg")

# %% [markdown]
# # Generators

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)
train_dir = "/content/train"
test_dir = "/content/test"

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(224, 224),
        batch_size=30,
        class_mode='binary')

test_generator=test_datagen.flow_from_directory(
        test_dir,
        target_size=(224,224),
        batch_size=30,
        class_mode='binary')
# Out:
# Found 375 images belonging to 2 classes.
# Found 125 images belonging to 2 classes.

# %% [markdown]
# # Model training

# %%
model = model_function(input_shape = (224, 224, 3))
model.compile(loss='binary_crossentropy', optimizer="adam", metrics = ["accuracy"])

history = model.fit(
              train_generator,
              steps_per_epoch=len(y_train)//30,
              epochs=20,
              validation_data=test_generator,
              validation_steps=len(y_test)//30)
# Out:
# Epoch 1/20
# 12/12 [==============================] - 6s 492ms/step - loss: 0.8976 - accuracy: 0.4551 - val_loss: 0.4444 - val_accuracy: 0.8083
# Epoch 2/20
# 12/12 [==============================] - 3s 263ms/step - loss: 0.4025 - accuracy: 0.8435 - val_loss: 0.1689 - val_accuracy: 0.9474
# Epoch 3/20
# 12/12 [==============================] - 3s 264ms/step - loss: 0.2248 - accuracy: 0.9565 - val_loss: 0.1712 - val_accuracy: 0.9789
# Epoch 4/20
# 12/12 [==============================] - 3s 272ms/step - loss: 0.1691 - accuracy: 0.9694 - val_loss: 0.1533 - val_accuracy: 0.9684
# Epoch 5/20
# 12/12 [==============================] - 3s 251ms/step - loss: 0.1550 - accuracy: 0.9636 - val_loss: 0.0290 - val_accuracy: 0.9789
# Epoch 6/20
# 12/12 [==============================] - 3s 281ms/step - loss: 0.1086 - accuracy: 0.9806 - val_loss: 0.2340 - val_accuracy: 0.9750
# Epoch 7/20
# 12/12 [==============================] - 3s 251ms/step - loss: 0.1173 - accuracy: 0.9636 - val_loss: 0.0566 - val_accuracy: 0.9789
# Epoch 8/20
# 12/12 [==============================] - 3s 272ms/step - loss: 0.0964 - accuracy: 0.9778 - val_loss: 0.1626 - val_accuracy: 0.9789
# Epoch 9/20
# 12/12 [==============================] - 3s 255ms/step - loss: 0.0949 - accuracy: 0.9727 - val_loss: 0.1156 - val_accuracy: 0.9684
# Epoch 10/20
# 12/12 [==============================] - 3s 266ms/step - loss: 0.0900 - accuracy: 0.9806 - val_loss: 0.0406 - val_accuracy: 0.9789
# Epoch 11/20
# 12/12 [==============================] - 3s 273ms/step - loss: 0.0809 - accuracy: 0.9826 - val_loss: 0.1361 - val_accuracy: 0.9750
# Epoch 12/20
# 12/12 [==============================] - 3s 263ms/step - loss: 0.0908 - accuracy: 0.9797 - val_loss: 0.1705 - val_accuracy: 0.9789
# Epoch 13/20
# 12/12 [==============================] - 3s 263ms/step - loss: 0.0792 - accuracy: 0.9768 - val_loss: 0.1749 - val_accuracy: 0.9684
# Epoch 14/20
# 12/12 [==============================] - 3s 262ms/step - loss: 0.0685 - accuracy: 0.9855 - val_loss: 0.0792 - val_accuracy: 0.9789
# Epoch 15/20
# 12/12 [==============================] - 3s 258ms/step - loss: 0.0843 - accuracy: 0.9768 - val_loss: 0.0233 - val_accuracy: 0.9789
# Epoch 16/20
# 12/12 [==============================] - 3s 281ms/step - loss: 0.0894 - accuracy: 0.9639 - val_loss: 0.0552 - val_accuracy: 0.9750
# Epoch 17/20
# 12/12 [==============================] - 3s 259ms/step - loss: 0.0783 - accuracy: 0.9758 - val_loss: 0.2103 - val_accuracy: 0.9684
# Epoch 18/20
# 12/12 [==============================] - 3s 264ms/step - loss: 0.0652 - accuracy: 0.9797 - val_loss: 0.0445 - val_accuracy: 0.9789
# Epoch 19/20
# 12/12 [==============================] - 3s 271ms/step - loss: 0.0827 - accuracy: 0.9722 - val_loss: 0.1143 - val_accuracy: 0.9789
# Epoch 20/20
# 12/12 [==============================] - 3s 258ms/step - loss: 0.0768 - accuracy: 0.9739 - val_loss: 0.0992 - val_accuracy: 0.9789

# %% [markdown]
# # Model loss and accuracy

# %%
plt.figure(figsize=(15,6))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# %%
model.save("/content/drive/My Drive/Colab/Roonyx/Face recognition/07.06.2020/MODEL_female_male_resnet.h5")

# %% [markdown]
# # Example of prediction

# %%
images = test_generator.next()[0]
images = images[:10]

labels = []
for i in range(0,len(images),1):
  if(model.predict(images[i:i+1]) < 0.5):
    labels.append("female")
  else: labels.append("male")

fix,axes = plt.subplots(2,5, figsize=(18,8), subplot_kw={'xticks':(),'yticks':()})
for img, label, ax in zip(images, labels, axes.ravel()):
    ax.imshow(img, cmap=plt.cm.binary)
    ax.set_title(label)

# %% [markdown]
# # Predictions on all test images

# %%
import os 
from skimage import io

num_true = 0
num_false = 0

file_names = os.listdir("/content/test/female")
for file in file_names:
  image = io.imread("/content/test/female/" + str(file))
  y_pred = model.predict(np.array([image])/255)
  if y_pred < 0.5:
    num_true+=1
  else: num_false+=1

file_names = os.listdir("/content/test/male")
for file in file_names:
  image = io.imread("/content/test/male/" + str(file))
  y_pred = model.predict(np.array([image])/255)
  if y_pred > 0.5:
    num_true+=1
  else: num_false+=1

print("num true: ", num_true)
print("num false: ", num_false)
print("Accuracy: {:.2f}%".format(num_true/((num_true+num_false)/100)))
# Out:
# num true:  122
# num false:  3
# Accuracy: 97.60%
